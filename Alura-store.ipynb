# %% [markdown]
# # **Bibliotecas**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # **Importación de datasets**

# %%
tienda_1 = pd.read_csv('tienda1.csv')
tienda_2 = pd.read_csv('tienda2.csv')
tienda_3 = pd.read_csv('tienda3.csv')
tienda_4 = pd.read_csv('tienda4.csv')

tienda_1.head()
# Out:
#             Producto Categoría del Producto    Precio  Costo de envío  \
# 0  Asistente virtual           Electrónicos  164300.0          6900.0
# 1    Mesa de comedor                Muebles  192300.0          8400.0
# 2      Juego de mesa               Juguetes  209600.0         15900.0
# 3         Microondas      Electrodomésticos  757500.0         41000.0
# 4   Silla de oficina                Muebles  335200.0         20200.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      16/01/2021      Pedro Gomez          Bogotá             4
# 1      18/05/2022  Beatriz Morales        Medellín             1
# 2      15/03/2021   Juan Fernandez       Cartagena             1
# 3      03/05/2022   Juan Fernandez            Cali             4
# 4      07/11/2020    Maria Alfonso        Medellín             5
#
#        Método de pago  Cantidad de cuotas       lat       lon
# 0  Tarjeta de crédito                   8   4.60971 -74.08175
# 1  Tarjeta de crédito                   4   6.25184 -75.56359
# 2  Tarjeta de crédito                   1  10.39972 -75.51444
# 3               Nequi                   1   3.43722 -76.52250
# 4               Nequi                   1   6.25184 -75.56359

# %%
tienda_1.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2359 entries, 0 to 2358
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Producto                2359 non-null   str
#  1   Categoría del Producto  2359 non-null   str
#  2   Precio                  2359 non-null   float64
#  3   Costo de envío          2359 non-null   float64
#  4   Fecha de Compra         2359 non-null   str
#  5   Vendedor                2359 non-null   str
#  6   Lugar de Compra         2359 non-null   str
#  7   Calificación            2359 non-null   int64
#  8   Método de pago          2359 non-null   str
#  9   Cantidad de cuotas      2359 non-null   int64
#  10  lat                     2359 non-null   float64
#  11  lon                     2359 non-null   float64
# dtypes: float64(4), int64(2), str(6)
# memory usage: 221.3 KB

# %%
tienda_2.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2359 entries, 0 to 2358
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Producto                2359 non-null   str
#  1   Categoría del Producto  2359 non-null   str
#  2   Precio                  2359 non-null   float64
#  3   Costo de envío          2359 non-null   float64
#  4   Fecha de Compra         2359 non-null   str
#  5   Vendedor                2359 non-null   str
#  6   Lugar de Compra         2359 non-null   str
#  7   Calificación            2359 non-null   int64
#  8   Método de pago          2359 non-null   str
#  9   Cantidad de cuotas      2359 non-null   int64
#  10  lat                     2359 non-null   float64
#  11  lon                     2359 non-null   float64
# dtypes: float64(4), int64(2), str(6)
# memory usage: 221.3 KB

# %%
tienda_3.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2359 entries, 0 to 2358
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Producto                2359 non-null   str
#  1   Categoría del Producto  2359 non-null   str
#  2   Precio                  2359 non-null   float64
#  3   Costo de envío          2359 non-null   float64
#  4   Fecha de Compra         2359 non-null   str
#  5   Vendedor                2359 non-null   str
#  6   Lugar de Compra         2359 non-null   str
#  7   Calificación            2359 non-null   int64
#  8   Método de pago          2359 non-null   str
#  9   Cantidad de cuotas      2359 non-null   int64
#  10  lat                     2359 non-null   float64
#  11  lon                     2359 non-null   float64
# dtypes: float64(4), int64(2), str(6)
# memory usage: 221.3 KB

# %%
tienda_4.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2358 entries, 0 to 2357
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Producto                2358 non-null   str
#  1   Categoría del Producto  2358 non-null   str
#  2   Precio                  2358 non-null   float64
#  3   Costo de envío          2358 non-null   float64
#  4   Fecha de Compra         2358 non-null   str
#  5   Vendedor                2358 non-null   str
#  6   Lugar de Compra         2358 non-null   str
#  7   Calificación            2358 non-null   int64
#  8   Método de pago          2358 non-null   str
#  9   Cantidad de cuotas      2358 non-null   int64
#  10  lat                     2358 non-null   float64
#  11  lon                     2358 non-null   float64
# dtypes: float64(4), int64(2), str(6)
# memory usage: 221.2 KB

# %% [markdown]
# # **Análisis de facturación**

# %% [markdown]
# ## **Ingreso total por tienda**

# %%
tienda_1["Tienda"] = "Tienda 1"
tienda_2["Tienda"] = "Tienda 2"
tienda_3["Tienda"] = "Tienda 3"
tienda_4["Tienda"] = "Tienda 4"

tiendas = pd.concat([tienda_1, tienda_2, tienda_3, tienda_4], ignore_index=True)

# %%
tiendas.sample(5)
# Out:
#                Producto   Categoría del Producto     Precio  Costo de envío  \
# 5467             Estufa        Electrodomésticos   513100.0         25500.0
# 4050       Set de ollas  Artículos para el hogar   189700.0         10300.0
# 7419  Balón de voleibol     Deportes y diversión    43400.0             0.0
# 9179             Sillón                  Muebles   291200.0         15900.0
# 310       TV LED UHD 4K             Electrónicos  2394900.0        125700.0
#
#      Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 5467      24/05/2020   Blanca Ramirez          Bogotá             5
# 4050      13/12/2022    Rafael Acosta        Medellín             4
# 7419      08/04/2022  Mariana Herrera         Leticia             4
# 9179      13/02/2022  Mariana Herrera           Pasto             5
# 310       15/12/2022    Camila Rivera        Medellín             5
#
#           Método de pago  Cantidad de cuotas      lat       lon    Tienda
# 5467  Tarjeta de crédito                   1  4.60971 -74.08175  Tienda 3
# 4050  Tarjeta de crédito                   6  6.25184 -75.56359  Tienda 2
# 7419  Tarjeta de crédito                   3 -4.21528 -69.94056  Tienda 4
# 9179  Tarjeta de crédito                   3  1.21361 -77.28111  Tienda 4
# 310   Tarjeta de crédito                   1  6.25184 -75.56359  Tienda 1

# %%
ingresos_totales = (
    tiendas.groupby('Tienda')['Precio']
    .sum()
    .map("{:,.2f}".format)
    .sort_values(ascending=True)
)
ingresos_totales
# Out:
# Tienda
# Tienda 4    1,038,375,700.00
# Tienda 3    1,098,019,600.00
# Tienda 2    1,116,343,500.00
# Tienda 1    1,150,880,400.00
# Name: Precio, dtype: str

# %% [markdown]
# ## **Ventas por categoría**

# %%
tiendas['Categoría del Producto'].unique()
# Out:
# <StringArray>
# [           'Electrónicos',                 'Muebles',
#                 'Juguetes',       'Electrodomésticos',
#  'Artículos para el hogar',    'Deportes y diversión',
#                   'Libros',  'Instrumentos musicales']
# Length: 8, dtype: str

# %%
ventas_categoria = (
    tiendas.groupby('Tienda')['Categoría del Producto']
    .value_counts()
    .reset_index(name='Ventas')
)
ventas_categoria
# Out:
#       Tienda   Categoría del Producto  Ventas
# 0   Tienda 1                  Muebles     465
# 1   Tienda 1             Electrónicos     448
# 2   Tienda 1                 Juguetes     324
# 3   Tienda 1        Electrodomésticos     312
# 4   Tienda 1     Deportes y diversión     284
# 5   Tienda 1   Instrumentos musicales     182
# 6   Tienda 1                   Libros     173
# 7   Tienda 1  Artículos para el hogar     171
# 8   Tienda 2                  Muebles     442
# 9   Tienda 2             Electrónicos     422
# 10  Tienda 2                 Juguetes     313
# 11  Tienda 2        Electrodomésticos     305
# 12  Tienda 2     Deportes y diversión     275
# 13  Tienda 2   Instrumentos musicales     224
# 14  Tienda 2                   Libros     197
# 15  Tienda 2  Artículos para el hogar     181
# 16  Tienda 3                  Muebles     499
# 17  Tienda 3             Electrónicos     451
# 18  Tienda 3                 Juguetes     315
# 19  Tienda 3        Electrodomésticos     278
# 20  Tienda 3     Deportes y diversión     277
# 21  Tienda 3                   Libros     185
# 22  Tienda 3  Artículos para el hogar     177
# 23  Tienda 3   Instrumentos musicales     177
# 24  Tienda 4                  Muebles     480
# 25  Tienda 4             Electrónicos     451
# 26  Tienda 4                 Juguetes     338
# 27  Tienda 4     Deportes y diversión     277
# 28  Tienda 4        Electrodomésticos     254
# 29  Tienda 4  Artículos para el hogar     201
# 30  Tienda 4                   Libros     187
# 31  Tienda 4   Instrumentos musicales     170

# %% [markdown]
# ## **Valoración media por tienda**

# %%
#Tienda mejor valorada
valoración_media = (
    tiendas.groupby('Tienda')['Calificación']
    .mean()
    .reset_index()
    .sort_values('Calificación', ascending=False)
)
valoración_media
# Out:
#      Tienda  Calificación
# 2  Tienda 3      4.048326
# 1  Tienda 2      4.037304
# 3  Tienda 4      3.995759
# 0  Tienda 1      3.976685

# %% [markdown]
# ## **Productos más y menos vendidos**

# %%
# Lista de todos los productos que se venden en las 4 tiendas
productos_totales = tiendas['Producto'].unique()
productos_totales
# Out:
# <StringArray>
# [          'Asistente virtual',             'Mesa de comedor',
#                'Juego de mesa',                  'Microondas',
#             'Silla de oficina',     'Bloques de construcción',
#                  'Muñeca bebé',                'Lavavajillas',
#             'Lavadora de ropa',   'Carrito de control remoto',
#                 'Refrigerador',                 'Auriculares',
#              'Olla de presión',                   'Bicicleta',
#  'Ciencia de datos con Python',           'Balón de voleibol',
#            'Ajedrez de madera',               'TV LED UHD 4K',
#                 'Vaso térmico',               'Kit de bancas',
#      'Dashboards con Power BI',                  'Cubertería',
#                 'Set de ollas',                     'Batería',
#           'Cuerda para saltar',                      'Estufa',
#                     'Cama box',                   'Impresora',
#                'Mesa de noche',                     'Armario',
#               'Dinosaurio Rex',          'Guitarra eléctrica',
#             'Secadora de ropa',             'Sofá reclinable',
#                  'Tablet ABXY',             'Cubo mágico 8x8',
#                 'Set de vasos',         'Modelado predictivo',
#                    'Iphone 15',                     'Mochila',
#          'Balón de baloncesto',   'Auriculares con micrófono',
#                       'Sillón',           'Guitarra acústica',
#    'Iniciando en programación',                'Celular ABXY',
#                   'Smartwatch',              'Mesa de centro',
#                    'Cama king',                    'Smart TV',
#                    'Pandereta']
# Length: 51, dtype: str

# %%
ventas_producto = (
    tiendas.groupby(['Tienda', 'Producto'])
    .size()
    .reset_index(name = 'Ventas')
)
ventas_producto.sample(10)
# Out:
#        Tienda                   Producto  Ventas
# 37   Tienda 1            Olla de presión      35
# 106  Tienda 3  Auriculares con micrófono      39
# 51   Tienda 2          Ajedrez de madera      45
# 162  Tienda 4    Bloques de construcción      54
# 141  Tienda 3               Refrigerador      50
# 169  Tienda 4            Cubo mágico 8x8      47
# 111  Tienda 3    Bloques de construcción      35
# 68   Tienda 2         Cuerda para saltar      50
# 43   Tienda 1           Silla de oficina      46
# 170  Tienda 4         Cuerda para saltar      43

# %%
mas_vendidos = (
    ventas_producto
    .sort_values(['Tienda', 'Ventas'], ascending=[True, False])
    .groupby('Tienda')
    .head(10)
)

mas_vendidos
# Out:
#        Tienda                   Producto  Ventas
# 1    Tienda 1                    Armario      60
# 33   Tienda 1                 Microondas      60
# 48   Tienda 1              TV LED UHD 4K      60
# 40   Tienda 1           Secadora de ropa      58
# 9    Tienda 1    Bloques de construcción      56
# 32   Tienda 1              Mesa de noche      56
# 5    Tienda 1        Balón de baloncesto      55
# 8    Tienda 1                  Bicicleta      54
# 23   Tienda 1                  Impresora      54
# 39   Tienda 1               Refrigerador      54
# 75   Tienda 2  Iniciando en programación      65
# 84   Tienda 2                 Microondas      62
# 58   Tienda 2                    Batería      61
# 72   Tienda 2          Guitarra acústica      58
# 89   Tienda 2                  Pandereta      58
# 91   Tienda 2           Secadora de ropa      57
# 76   Tienda 2                  Iphone 15      55
# 52   Tienda 2                    Armario      54
# 60   Tienda 2    Bloques de construcción      54
# 92   Tienda 2               Set de ollas      52
# 129  Tienda 3              Kit de bancas      57
# 113  Tienda 3                  Cama king      56
# 133  Tienda 3            Mesa de comedor      56
# 134  Tienda 3              Mesa de noche      55
# 143  Tienda 3               Set de ollas      55
# 147  Tienda 3                   Smart TV      54
# 119  Tienda 3         Cuerda para saltar      53
# 122  Tienda 3                     Estufa      53
# 137  Tienda 3        Modelado predictivo      53
# 110  Tienda 3                  Bicicleta      52
# 163  Tienda 4                   Cama box      62
# 168  Tienda 4                 Cubertería      59
# 164  Tienda 4                  Cama king      56
# 171  Tienda 4    Dashboards con Power BI      56
# 165  Tienda 4  Carrito de control remoto      55
# 184  Tienda 4            Mesa de comedor      55
# 185  Tienda 4              Mesa de noche      55
# 162  Tienda 4    Bloques de construcción      54
# 198  Tienda 4                   Smart TV      54
# 191  Tienda 4                  Pandereta      52

# %%
menos_vendidos = (
    ventas_producto
    .sort_values(['Tienda', 'Ventas'], ascending=[True, True])
    .groupby('Tienda')
    .head(10)
)

menos_vendidos
# Out:
#        Tienda                     Producto  Ventas
# 4    Tienda 1    Auriculares con micrófono      33
# 13   Tienda 1                 Celular ABXY      33
# 37   Tienda 1              Olla de presión      35
# 38   Tienda 1                    Pandereta      36
# 14   Tienda 1  Ciencia de datos con Python      39
# 34   Tienda 1                      Mochila      39
# 2    Tienda 1            Asistente virtual      40
# 17   Tienda 1           Cuerda para saltar      40
# 19   Tienda 1               Dinosaurio Rex      40
# 31   Tienda 1              Mesa de comedor      40
# 77   Tienda 2                Juego de mesa      32
# 74   Tienda 2                    Impresora      34
# 82   Tienda 2              Mesa de comedor      34
# 95   Tienda 2                       Sillón      35
# 54   Tienda 2                  Auriculares      37
# 53   Tienda 2            Asistente virtual      38
# 66   Tienda 2                   Cubertería      39
# 96   Tienda 2                     Smart TV      40
# 64   Tienda 2                 Celular ABXY      41
# 56   Tienda 2          Balón de baloncesto      42
# 111  Tienda 3      Bloques de construcción      35
# 135  Tienda 3                   Microondas      36
# 136  Tienda 3                      Mochila      36
# 144  Tienda 3                 Set de vasos      36
# 124  Tienda 3           Guitarra eléctrica      38
# 152  Tienda 3                 Vaso térmico      38
# 104  Tienda 3            Asistente virtual      39
# 106  Tienda 3    Auriculares con micrófono      39
# 117  Tienda 3                   Cubertería      39
# 138  Tienda 3                  Muñeca bebé      39
# 175  Tienda 4           Guitarra eléctrica      33
# 154  Tienda 4                      Armario      34
# 174  Tienda 4            Guitarra acústica      37
# 167  Tienda 4  Ciencia de datos con Python      38
# 181  Tienda 4             Lavadora de ropa      38
# 192  Tienda 4                 Refrigerador      38
# 153  Tienda 4            Ajedrez de madera      39
# 166  Tienda 4                 Celular ABXY      39
# 199  Tienda 4                   Smartwatch      39
# 193  Tienda 4             Secadora de ropa      40

# %%
resumen = pd.merge(
    mas_vendidos,
    menos_vendidos,
    on = 'Tienda',
    suffixes = ('Más Vendidos', 'Menos Vendidos')
)
resumen
# Out:
#        Tienda ProductoMás Vendidos  VentasMás Vendidos  \
# 0    Tienda 1              Armario                  60
# 1    Tienda 1              Armario                  60
# 2    Tienda 1              Armario                  60
# 3    Tienda 1              Armario                  60
# 4    Tienda 1              Armario                  60
# ..        ...                  ...                 ...
# 395  Tienda 4            Pandereta                  52
# 396  Tienda 4            Pandereta                  52
# 397  Tienda 4            Pandereta                  52
# 398  Tienda 4            Pandereta                  52
# 399  Tienda 4            Pandereta                  52
#
#           ProductoMenos Vendidos  VentasMenos Vendidos
# 0      Auriculares con micrófono                    33
# 1                   Celular ABXY                    33
# 2                Olla de presión                    35
# 3                      Pandereta                    36
# 4    Ciencia de datos con Python                    39
# ..                           ...                   ...
# 395                 Refrigerador                    38
# 396            Ajedrez de madera                    39
# 397                 Celular ABXY                    39
# 398                   Smartwatch                    39
# 399             Secadora de ropa                    40
#
# [400 rows x 5 columns]

# %%
#Top 5 productos más vendidos por tienda
top5 = (
    ventas_producto
    .sort_values(['Tienda', 'Ventas'], ascending=[True, False])
    .groupby('Tienda')
    .head(5)
)

for tienda in top5['Tienda'].unique():

    df_tienda = top5[top5['Tienda'] == tienda]

    plt.figure()
    plt.bar(df_tienda['Producto'], df_tienda['Ventas'])
    plt.title(f'Top 5 productos más vendidos - {tienda}')
    plt.xticks(rotation=45)
    plt.ylabel('Número de ventas')
    plt.show()

# %%
#Top 5 productos menos vendidos por tienda
bottom5 = (
    ventas_producto
    .sort_values(['Tienda', 'Ventas'], ascending=[True, True])
    .groupby('Tienda')
    .head(5)
)

for tienda in bottom5['Tienda'].unique():

    df_tienda = bottom5[bottom5['Tienda'] == tienda]

    plt.figure()
    plt.bar(df_tienda['Producto'], df_tienda['Ventas'])
    plt.title(f'Top 5 productos menos vendidos - {tienda}')
    plt.xticks(rotation=45)
    plt.ylabel('Número de ventas')
    plt.show()

# %%
for tienda in ventas_producto['Tienda'].unique():
    df_tienda = ventas_producto[ventas_producto['Tienda'] == tienda]
    
    masvendido = df_tienda.loc[df_tienda['Ventas'].idxmax()]
    menosvendido = df_tienda.loc[df_tienda['Ventas'].idxmin()]

    print('--------------------------------------------')
    print('Tienda:', tienda)
    print('El producto más vendido es:', masvendido['Producto'], 'con', masvendido['Ventas'], 'unidades vendidas')
    print('El producto menos vendido es:', menosvendido["Producto"], 'con', menosvendido['Ventas'], 'unidades vendidas')
# Out:
# --------------------------------------------
# Tienda: Tienda 1
# El producto más vendido es: Armario con 60 unidades vendidas
# El producto menos vendido es: Auriculares con micrófono con 33 unidades vendidas
# --------------------------------------------
# Tienda: Tienda 2
# El producto más vendido es: Iniciando en programación con 65 unidades vendidas
# El producto menos vendido es: Juego de mesa con 32 unidades vendidas
# --------------------------------------------
# Tienda: Tienda 3
# El producto más vendido es: Kit de bancas con 57 unidades vendidas
# El producto menos vendido es: Bloques de construcción con 35 unidades vendidas
# --------------------------------------------
# Tienda: Tienda 4
# El producto más vendido es: Cama box con 62 unidades vendidas
# El producto menos vendido es: Guitarra eléctrica con 33 unidades vendidas

# %% [markdown]
# ## **Valor del envío promedio por tienda**

# %%
costo_envio_promedio = (
    tiendas.groupby('Tienda')['Costo de envío']
    .mean()
    .reset_index()
    .sort_values('Costo de envío', ascending=False)
)
costo_envio_promedio
# Out:
#      Tienda  Costo de envío
# 0  Tienda 1    26018.609580
# 1  Tienda 2    25216.235693
# 2  Tienda 3    24805.680373
# 3  Tienda 4    23459.457167

# %% [markdown]
# # **Visualización**

# %%
tiendas.sample(5)
# Out:
#                Producto   Categoría del Producto     Precio  Costo de envío  \
# 6547  Balón de voleibol     Deportes y diversión    52700.0          3500.0
# 3427           Smart TV             Electrónicos  1206000.0         64600.0
# 5897          Impresora             Electrónicos   374800.0         20700.0
# 4657       Vaso térmico     Deportes y diversión    38500.0          2600.0
# 5208    Olla de presión  Artículos para el hogar    76200.0          2200.0
#
#      Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 6547      06/03/2021  Mariana Herrera         Inírida             3
# 3427      18/04/2022    Felipe Santos         Leticia             5
# 5897      06/08/2021  Mariana Herrera          Bogotá             5
# 4657      08/03/2023   Juan Fernandez            Cali             3
# 5208      14/06/2022  Ángel Rodriguez            Cali             5
#
#           Método de pago  Cantidad de cuotas      lat       lon    Tienda
# 6547  Tarjeta de crédito                   2  3.86530 -67.92390  Tienda 3
# 3427  Tarjeta de crédito                   1 -4.21528 -69.94056  Tienda 2
# 5897  Tarjeta de crédito                   1  4.60971 -74.08175  Tienda 3
# 4657  Tarjeta de crédito                   2  3.43722 -76.52250  Tienda 2
# 5208  Tarjeta de crédito                   1  3.43722 -76.52250  Tienda 3

# %% [markdown]
# ## **Ingreso total por tiendas**

# %%
fig, ax = plt.subplots(figsize=(12, 8))

tienda = ingresos_totales.axes[0].tolist()
ingreso = ingresos_totales.values.tolist()
bar_colors = ['orange', 'forestgreen', 'orchid', 'purple']

ax.bar(tienda, ingreso, color=bar_colors)

ax.set_xlabel('Tienda')
ax.set_ylabel('Ingresos Totales')
ax.set_title('Ingresos Totales por Tienda')
ax.invert_xaxis()

plt.show()

# %% [markdown]
# ## **Productos más y menos vendidos**

# %%
pivot_mas = top5.pivot_table(
    index='Producto',
    columns='Tienda',
    values='Ventas',
    fill_value=0
)

pivot_mas.plot(kind='bar', stacked=True, figsize=(10, 6))

plt.title('Top productos más vendidos (comparación por tienda)')
plt.ylabel("Ventas")
plt.xticks(rotation=90)
plt.show()

# %%
pivot_menos = bottom5.pivot_table(
    index='Producto',
    columns='Tienda',
    values='Ventas',
    fill_value=0
)

pivot_menos.plot(kind='bar', stacked=True, figsize=(10, 6))

plt.title('Top productos menos vendidos (comparación por tienda)')
plt.ylabel("Ventas")
plt.xticks(rotation=90)
plt.show()

# %%
#TODO:Generar grafico de cada tipo de pago por tienda
pagos_tienda = (
    tiendas.groupby(['Tienda', 'Método de pago'])
    .size()
    .reset_index(name = 'Pagos')
)

for tienda in pagos_tienda['Tienda'].unique():

    df_tienda = pagos_tienda[pagos_tienda['Tienda'] == tienda]

    plt.figure(figsize=(6,6))

    plt.pie(
        df_tienda['Pagos'],
        labels=df_tienda['Método de pago'],
        autopct="%1.1f%%",
        startangle=90,
        textprops={'fontsize': 10},
        pctdistance=0.9
    )

    plt.title(f'Distribución de métodos de pago - Tienda {tienda}')
    plt.show()
